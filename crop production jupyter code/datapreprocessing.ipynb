# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv(r"C:\Users\sunda\Downloads\crop_production_data.csv")

# %%
df['Production'] = df['Production'].fillna(df['Production'].mean())

# %%
df = pd.get_dummies(df, columns=['State_Name', 'District_Name', 'Season'])

# %%
# Scale Numerical Features
scaler = MinMaxScaler()
df[['Area', 'Crop_Year']] = scaler.fit_transform(df[['Area', 'Crop_Year']])

# %%
# Display the first few rows of the preprocessed DataFrame
print(df.head())
# Out:
#    Crop_Year                 Crop          Area  Production  \
# 0   0.166667             Arecanut  1.461475e-04      2000.0
# 1   0.166667  Other Kharif pulses  2.284356e-07         1.0
# 2   0.166667                 Rice  1.188331e-05       321.0
# 3   0.166667               Banana  2.050792e-05       641.0
# 4   0.166667            Cashewnut  8.391044e-05       165.0
#
#    State_Name_Andaman and Nicobar Islands  State_Name_Andhra Pradesh  \
# 0                                    True                      False
# 1                                    True                      False
# 2                                    True                      False
# 3                                    True                      False
# 4                                    True                      False
#
#    State_Name_Arunachal Pradesh  State_Name_Assam  State_Name_Bihar  \
# 0                         False             False             False
# 1                         False             False             False
# 2                         False             False             False
# 3                         False             False             False
# 4                         False             False             False
#
#    State_Name_Chandigarh  ...  District_Name_YAMUNANAGAR  District_Name_YANAM  \
# 0                  False  ...                      False                False
# 1                  False  ...                      False                False
# 2                  False  ...                      False                False
# 3                  False  ...                      False                False
# 4                  False  ...                      False                False
#
#    District_Name_YAVATMAL  District_Name_ZUNHEBOTO  Season_Autumn       \
# 0                   False                    False               False
# 1                   False                    False               False
# 2                   False                    False               False
# 3                   False                    False               False
# 4                   False                    False               False
#
#    Season_Kharif       Season_Rabi         Season_Summer       \
# 0                True               False               False
# 1                True               False               False
# 2                True               False               False
# 3               False               False               False
# 4               False               False               False
#
#    Season_Whole Year   Season_Winter
# 0               False               False
# 1               False               False
# 2               False               False
# 3                True               False
# 4                True               False
#
# [5 rows x 689 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv(r"C:\Users\sunda\Downloads\crop_production_data.csv")

# %%
# Step 3: Preprocess your data
# Drop rows with missing values in the target variable
df = df.dropna(subset=['Production'])

# %%
# Step 4: Split the dataset into features (X) and target variable (y)
X = df.drop(columns=['Production'])  # Features
y = df['Production']  # Target variable

# %%
# Step 5: Encode categorical variables using one-hot encoding
X_encoded = pd.get_dummies(X)

# %%
# Step 6: Split the encoded dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
# Step 7: Train the model
linear_reg_model = LinearRegression()
linear_reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Step 8: Make predictions on the testing data
linear_reg_predictions = linear_reg_model.predict(X_test)

# %%
# Step 9: Evaluate the model's performance
linear_reg_mae = mean_absolute_error(y_test, linear_reg_predictions)
linear_reg_mse = mean_squared_error(y_test, linear_reg_predictions)
linear_reg_r2 = r2_score(y_test, linear_reg_predictions)

# %%
print("Linear Regression Metrics:")
print("Mean Absolute Error (MAE):", linear_reg_mae)
print("Mean Squared Error (MSE):", linear_reg_mse)
print("R-squared (R2):", linear_reg_r2)
# Out:
# Linear Regression Metrics:
# Mean Absolute Error (MAE): 1926724.7458613564
# Mean Squared Error (MSE): 330386814616052.6
# R-squared (R2): 0.17883228777143167
